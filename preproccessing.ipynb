# %%
import torchaudio
#Preprocessing for ResNet
torchaudio.set_audio_backend("sox_io")
import glob
import os
import pandas as pd
import torchaudio
import torch
import torch.nn as nn
from torchaudio import transforms as T
import h5py
import numpy as np

#paths to our training/validation sets
train_path = "/Users/zaher/Desktop/Project/Training_Set"
val_path = "/Users/zaher/Desktop/Project/Validation_Set"


#parameters for Audio Preproccessing
TARGET_SR = 22050
N_FFT = 1024
N_MELS = 128
HOP_MEL = 256
FMIN = 0
FMAX = TARGET_SR // 2
fps = TARGET_SR / HOP_MEL
WIN_LEN = 1000
SEG_LEN = WIN_LEN // 2
win_len = int(round((WIN_LEN / 1000) * fps))
seg_hop = int(round((SEG_LEN / 1000) * fps))
#transformations that converts audo parameters into Mel spectrograms and then we convert that to decibel 
mel = T.MelSpectrogram(sample_rate=TARGET_SR, n_fft=N_FFT, hop_length=HOP_MEL, f_min=FMIN, f_max=FMAX, n_mels=N_MELS)
transformation = nn.Sequential(mel, T.AmplitudeToDB())

#this function proccesses audio file
def PRE_process_audio(wav_file, df, is_training=True):
    #first of all we load the audio file then we RESAMPLE it to the target sample rate
    wav, sr = torchaudio.load(wav_file)
    resample = T.Resample(sr, TARGET_SR)
    wav = resample(wav)
    if wav.shape[0] != 1:
        wav = torch.mean(wav, dim=0, keepdim=True)
        #and finally apply the trainsformation to our wav file
    melspec = transformation(wav)
    #then we create lists to store these data segments their labels start and end time for each action

    segments = []
    labels = []
    start_times = []
    end_times = []

    for i in range(len(df)):
        #now we iterate over all of the rows in our CSV 
        row_num = df.iloc[i]
        if is_training:
            #give a default label to all of the values as 0 then if the label is positive we change it to 1 to distiinguish
            label = 0
            for col in df.columns:
                if col not in ['Audiofilename', 'Starttime', 'Endtime']:
                    #if the label is positive change it's label attribute to 1 for that ith row
                    if row_num[col] == 'POS':
                        label = 1
                        break
        else:
            label = 1 

        onset = int(round(row_num['Starttime'] * fps))
        offset = int(round(row_num['Endtime'] * fps))
        start_idx = onset

        #now we check if our segment is larger than window length if it is then we split it into smaller windows

        if offset - start_idx > win_len:
            while offset - start_idx > win_len:
                spec = melspec[:, :, start_idx:start_idx + win_len]
                if spec.sum() == 0 or torch.isnan(spec).any():
                    start_idx += seg_hop
                    continue
                    #normalise our segment
                spec = (spec - spec.min()) / (spec.max() - spec.min())
                segments.append(spec)
                labels.append(label)
                start_times.append(start_idx / fps)
                end_times.append((start_idx + win_len) / fps)
                start_idx += seg_hop
                #else if the segment is shorter we need to pad it
        else:
            if offset - start_idx > win_len // 8:
                spec = melspec[:, :, start_idx:offset]
                if spec.sum() == 0 or torch.isnan(spec).any():
                    continue
                spec = torch.nn.functional.pad(spec, (0, win_len - spec.shape[-1]))
                spec = (spec - spec.min()) / (spec.max() - spec.min())
                segments.append(spec)
                labels.append(label)
                start_times.append(start_idx / fps)
                end_times.append(offset / fps)
#we return our segment with it's labels start and end time
    return segments, labels, start_times, end_times
#this funtion is to preproccess our dataset we call the PRE_proccess here
def preprocess_dataset(path, is_training=True):
    subdirs = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    all_data = []

    for subdir in subdirs:
        subdir_path = os.path.join(path, subdir)
        #find all CSV files in the directory
        csv_files = glob.glob(os.path.join(subdir_path, '*.csv'))

        for csv_file in csv_files:
            df = pd.read_csv(csv_file)
            #after we find csv files for each one we look for the same name but with a WAV file extension and make sure it exists
            wav_file = csv_file.replace('.csv', '.wav')
            if not os.path.exists(wav_file):
                print(f" skipping {wav_file} this file doesn't exist.")
                continue

            print(f"Processing {wav_file}.")
            #we send our csv file alongside wav file to preproccess function to preproccess it andd save it
            segments, labels, start_times, end_times = PRE_process_audio(wav_file, df, is_training)
            
            if len(segments) == 0:
                print(f"No segments were successfully extracted from {wav_file}")
                continue
            #add it to our array
            all_data.append({'file': os.path.basename(wav_file),
                'segments': segments,
                'labels': labels,
                'start_times': start_times,
                'end_times': end_times})
#retur our preproccessed data
    return all_data

print("Starting Preproccessing to Training Data")
train_data = preprocess_dataset(train_path, is_training=True)
# save the file into an h5 in the train/val path
hdf_Training = os.path.join(train_path, 'train_all.h5')
with h5py.File(hdf_Training, 'w') as hf:
    #go through the dataset and skip files with no extracted segments
    for i, item in enumerate(train_data):
        if len(item['segments']) == 0:
            print(f"Skipping {item['file']} as it doesn't have any extracted segments.")
            continue
            #create a group for each file
        group = hf.create_group(f'file_{i}')
        #save the file name alongside with the labels segments, start and end times
        group.create_dataset('file', data=item['file'])
        group.create_dataset('segments', data=torch.stack(item['segments']).numpy())
        group.create_dataset('labels', data=np.array(item['labels']))
        group.create_dataset('start_times', data=np.array(item['start_times']))
        group.create_dataset('end_times', data=np.array(item['end_times']))

print(f"Training data finished and has been saved to {hdf_Training}")

print("\nStarting Preproccessing to Training Data")
val_data = preprocess_dataset(val_path, is_training=False)

hdf_val = os.path.join(val_path, 'val_all.h5')
with h5py.File(hdf_val, 'w') as hf:
    for i, item in enumerate(val_data):
        if len(item['segments']) == 0:
            print(f"Skipping {item['file']} as it doesn't have any extracted segments.")
            continue
        group = hf.create_group(f'file_{i}')
        group.create_dataset('file', data=item['file'])
        group.create_dataset('segments', data=torch.stack(item['segments']).numpy())
        group.create_dataset('labels', data=np.array(item['labels']))
        group.create_dataset('start_times', data=np.array(item['start_times']))
        group.create_dataset('end_times', data=np.array(item['end_times']))

print(f"Validation data finished and has been saved to {hdf_val}")

print("Preprocessing completed.")
# Out:
# /var/folders/pg/22n8t2m906vc18bt44y5trf80000gn/T/ipykernel_22511/1610507738.py:3: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("sox_io")
# Starting Preproccessing to Training Data
# Processing /Users/zaher/Desktop/Project/Training_Set/MT/dcase_MK2.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/MT/dcase_MK1.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/BV/2015-09-25_04-00-00_unit10.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/BV/2015-10-14_23-59-59_unit05.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/BV/2015-09-11_06-00-00_unit07.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/BV/2015-09-21_06-00-00_unit05.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/BV/2015-09-04_08-04-59_unit03.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/HT/n1.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/HT/e1.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/HT/h1.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/HT/a1.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/HT/y1.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC141571.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC420542.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC356856.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC314697.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC484626.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC476854.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC131532.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC296053.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC486755.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/Training_Set/WMW/XC486755.wav
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC475965.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC479839.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC432145.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC31615.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC129156.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC478850.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC324343.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC469959.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC361804.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC184429.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC422019.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC343737.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC538478.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC416949.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC454603.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC422018.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC459669.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC417089.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC30134.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC26959.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC120411.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC141170.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC143954.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC485312.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC488409.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC422437.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC376956.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC519927.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC447442.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC511677.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC135278.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC449187.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC312051.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC134761.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC164817.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC511674.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC440361.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC357687.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC100954.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC134762.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC236456.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC245725.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC103243.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC263296.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC471768.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC477331.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC457036.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC144531.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC180605.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC318427.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC474017.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC357911.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC496443.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC522864.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC150591.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC379838.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC336861.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC67350.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC281359.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC364458.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC528227.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC538213.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC474019.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC544680.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC149153.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC511642.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC109629.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC100619.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC134219.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC467851.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC466742.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC511641.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC341211.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC526238.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC281357.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC379837.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC146712.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC365601.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC476146.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC379953.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC466157.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC501872.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC270427.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC100622.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC538943.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC483694.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC234105.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC510571.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC299495.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC473571.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC538941.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC299330.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC483906.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC135658.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/Training_Set/WMW/XC135658.wav
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC90713.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC448652.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC417425.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC448653.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC120730.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC315733.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC505960.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC483697.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC240134.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC522273.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC495092.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC142515.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC280997.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC186806.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC208705.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC180287.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC134051.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC416749.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC326162.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC196976.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC171445.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC428706.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC314267.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC100296.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC189883.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC252756.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC479978.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC185101.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC253273.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC171122.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC252757.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC189882.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC514029.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC550870.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC299191.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC487692.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC185104.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC317421.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC405096.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC42542.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC515865.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC41249.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC487693.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC440482.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC432572.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC181349.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC371002.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC519898.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC538467.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC510499.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC145121.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC188147.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC460195.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC406576.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC106971.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC42541.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC477007.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/WMW/XC538710.wav.
# Processing /Users/zaher/Desktop/Project/Training_Set/JD/sp4f1_2015_04_24-05_00_00_0002.wav.
# Training data finished and has been saved to /Users/zaher/Desktop/Project/Training_Set/train_all.h5
#
# Starting Preproccessing to Training Data
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB/BUK5_20180921_015906a.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB/BUK5_20161101_002104a.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB/BUK1_20181011_001004.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB/BUK1_20181013_023504.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB/BUK4_20161011_000804.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/Validation_Set/PB/BUK4_20161011_000804.wav
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB/BUK4_20171022_004304a.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw1.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw3.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw2.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw6.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw7.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw5.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw4.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw9.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw10.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw11.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw8.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw13.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw12.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw15.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PW/pw14.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB24/BUK5_20180921_015906a.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB24/BUK4_20160925_231604.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/Validation_Set/PB24/BUK4_20160925_231604.wav
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB24/BUK4_20161031_232104a.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/PB24/BUK5_20181007_011905.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_TEL_19-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_13-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/file_423_487.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_TEL_20-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_TEL_23-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_16-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_TEL_25-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/file_97_113.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_17-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/HB/R4_cleaned recording_TEL_24-10-17.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/ME/ME1.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/ME/ME2.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/RD/RD_06.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/RD/RD_05.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/RD/RD_04.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/RD/RD_01.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/RD/RD_03.wav.
# Processing /Users/zaher/Desktop/Project/Validation_Set/RD/RD_02.wav.
# Validation data finished and has been saved to /Users/zaher/Desktop/Project/Validation_Set/val_all.h5
# Preprocessing completed.

# %%
import torchaudio
import os
import pandas as pd
import torch
import torch.nn as nn
from torchaudio import transforms as T
import h5py
import numpy as np
import glob

#setting audio backend for Mac
torchaudio.set_audio_backend("sox_io")

#paths to evaluation dataset
eval_path = "/Users/zaher/Desktop/Project/eval_2"

#parameters for Audio Preprocessing
TARGET_SR = 22050
N_FFT = 1024
N_MELS = 128
HOP_MEL = 256
FMIN = 0
FMAX = TARGET_SR // 2
fps = TARGET_SR / HOP_MEL
WIN_LEN = 1000
SEG_LEN = WIN_LEN // 2
win_len = int(round((WIN_LEN / 1000) * fps))
seg_hop = int(round((SEG_LEN / 1000) * fps))

mel = torchaudio.transforms.MelSpectrogram(sample_rate=TARGET_SR, n_fft=N_FFT, hop_length=HOP_MEL, f_min=FMIN, f_max=FMAX, n_mels=N_MELS)
transformation = nn.Sequential(mel, torchaudio.transforms.AmplitudeToDB())

def PRE_process_audio(wav_file, df, is_training=False):
    wav, sr = torchaudio.load(wav_file)
    resample = torchaudio.transforms.Resample(sr, TARGET_SR)
    wav = resample(wav)
    
    if wav.shape[0] != 1:
        wav = torch.mean(wav, dim=0, keepdim=True)
    
    melspec = transformation(wav)
    
    segments = []
    labels = []
    start_times = []
    end_times = []

    for i in range(len(df)):
        row_num = df.iloc[i]
        label = 1  # Evaluation is assumed to be all positive as we are evaluating
    
        onset = int(round(row_num['Starttime'] * fps))
        offset = int(round(row_num['Endtime'] * fps))
        start_idx = onset

        if offset - start_idx > win_len:
            while offset - start_idx > win_len:
                spec = melspec[:, :, start_idx:start_idx + win_len]
                if spec.sum() == 0 or torch.isnan(spec).any():
                    start_idx += seg_hop
                    continue
                spec = (spec - spec.min()) / (spec.max() - spec.min())
                segments.append(spec)
                labels.append(label)
                start_times.append(start_idx / fps)
                end_times.append((start_idx + win_len) / fps)
                start_idx += seg_hop
        else:
            if offset - start_idx > win_len // 8:
                spec = melspec[:, :, start_idx:offset]
                if spec.sum() == 0 or torch.isnan(spec).any():
                    continue
                spec = torch.nn.functional.pad(spec, (0, win_len - spec.shape[-1]))
                spec = (spec - spec.min()) / (spec.max() - spec.min())
                segments.append(spec)
                labels.append(label)
                start_times.append(start_idx / fps)
                end_times.append(offset / fps)
    
    return segments, labels, start_times, end_times

def preprocess_dataset(path):
    subdirs = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
    all_data = []

    for subdir in subdirs:
        subdir_path = os.path.join(path, subdir)
        csv_files = glob.glob(os.path.join(subdir_path, '*.csv'))

        for csv_file in csv_files:
            df = pd.read_csv(csv_file)
            wav_file = csv_file.replace('.csv', '.wav')
            if not os.path.exists(wav_file):
                print(f"Skipping {wav_file} as it doesn't exist.")
                continue

            print(f"Processing {wav_file}.")
            segments, labels, start_times, end_times = PRE_process_audio(wav_file, df, is_training=False)
            
            if len(segments) == 0:
                print(f"No segments were successfully extracted from {wav_file}")
                continue
            
            all_data.append({
                'file': os.path.basename(wav_file),
                'segments': segments,
                'labels': labels,
                'start_times': start_times,
                'end_times': end_times
            })
    
    return all_data

def save_to_hdf5(data, path):
    with h5py.File(path, 'w') as hf:
        for i, item in enumerate(data):
            if len(item['segments']) == 0:
                print(f"Skipping {item['file']} as it doesn't have any extracted segments.")
                continue
            group = hf.create_group(f'file_{i}')
            group.create_dataset('file', data=item['file'])
            group.create_dataset('segments', data=torch.stack(item['segments']).numpy())
            group.create_dataset('labels', data=np.array(item['labels']))
            group.create_dataset('start_times', data=np.array(item['start_times']))
            group.create_dataset('end_times', data=np.array(item['end_times']))

print("\nStarting preprocessing of evaluation data...")
eval_data = preprocess_dataset(eval_path)
hdf_eval = os.path.join(eval_path, 'eval_all.h5')
save_to_hdf5(eval_data, hdf_eval)
print(f"Evaluation data saved to {hdf_eval}")

print("Preprocessing completed.")
# Out:
# /var/folders/pg/22n8t2m906vc18bt44y5trf80000gn/T/ipykernel_22511/2781677291.py:12: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("sox_io")
# Starting preprocessing of evaluation data...
# Processing /Users/zaher/Desktop/Project/eval_2/MGE/85MGE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/MGE/89MGE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/MGE/91MGE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/MS/E3_49_20190715_0150.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/MS/E3_49_20190715_0150.wav
# Processing /Users/zaher/Desktop/Project/eval_2/MS/E2_208_20190712_0150.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/MS/E4_49_20190804_0150.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/MS/E1_208_20190712_0150.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CT/ct3.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CT/ct2.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CT/ct1.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/CT/ct1.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU04.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU04.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU05.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU07.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU07.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU06.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU06.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU02.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU02.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU03.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU03.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU01.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU01.wav
# Processing /Users/zaher/Desktop/Project/eval_2/QU/QU08.wav.
# No segments were successfully extracted from /Users/zaher/Desktop/Project/eval_2/QU/QU08.wav
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_10.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_04.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_05.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_11.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_07.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_13.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_12.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_06.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_02.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_16.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_17.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_03.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_15.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_01.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_14.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_19.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_18.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE/CHE_09.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC01.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC02.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC12.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC06.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC07.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC05.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC11.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC10.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC04.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/DC/DC08.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CW/cw1300_DCASE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CW/cw1345_DCASE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CW/cw1315_DCASE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CW/cw1330_DCASE.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F09.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F08.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F18.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F19.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F14.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F15.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F17.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F03.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F02.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F12.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F06.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F07.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F13.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F05.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F11.wav.
# Processing /Users/zaher/Desktop/Project/eval_2/CHE23/CHE_F10.wav.
# Evaluation data saved to /Users/zaher/Desktop/Project/eval_2/eval_all.h5
# Preprocessing completed.
